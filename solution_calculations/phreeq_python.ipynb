# %%
import phreeqpython
import matplotlib.pyplot as plt
pp = phreeqpython.PhreeqPython('PdmaDatabase1.txt')

# %%
#solution = pp.add_solution_simple({'CaCl2':1.0,'NaHCO3':2.0})
sol = {
    'Cl': 0.02,
    'Na': 0.02,
    'Pdma': 0.000001,
    'Cu': 0.000001,
}
solution = pp.add_solution_simple(sol)
solution.change_ph(3.0)
solution.species
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[7], line 9
#       2 sol = {
#       3     'Cl': 0.02,
#       4     'Na': 0.02,
#       5     'Pdma': 0.000001,
#       6     'Cu': 0.000001,
#       7 }
#       8 solution = pp.add_solution_simple(sol)
# ----> 9 solution.change_ph(3.0)
#      10 solution.species
#
# File ~/miniconda3/envs/playground/lib/python3.10/site-packages/phreeqpython/solution.py:100, in Solution.change_ph(self, to_pH, with_chemical)
#      97 if not with_chemical:
#      98     if to_pH < self.pH:
#      99         # dose HCl to lower pH
# --> 100         self.pp.equalize_solution(self.number, "Fix_pH", -to_pH, 10, "HCl")
#     101     else:
#     102         # dose NaOH to raise pH
#     103         self.pp.equalize_solution(self.number, "Fix_pH", -to_pH, 10, "NaOH")
#
# ...
