# %%
from phreeqpython import PhreeqPython
# create new PhreeqPython instance
pp = PhreeqPython('/home/jjl122/repos/irp-jjl122/tests/test_database_1.dat')
import numpy as np
import matplotlib.pyplot as plt

# %%
sol = {
    'pH': 3.0,
    'Cl': 0.02,
    'Na': 0.02,
    'Ni': 0.00001,
    'Citrate': 0.00001,
    'Dfoba': 0.00001,
    'Dma': 0.00001,
    'Dmaoh': 0.00001,
    'Malate': 0.00001,
    'Co': 0.000001,
    'Cu': 0.000001,
    'Fe': 0.000001,
    'Zn': 0.000001,
    'units': 'mol/kgw',
    'pe': 5.92,
    'temperature': 25
}

# %%
try:
    solution = pp.add_solution(sol)
except Exception as e:
    print(e)
# Out:
# An error occured.
# ERROR: RunString: No database is loaded

# %%
solution.species
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 solution.species
#
# NameError: name 'solution' is not defined

# %%
# Sort the data by keys to ensure a proper line plot
sorted_data = dict(sorted(selected_species.items()))

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(list(sorted_data.keys()), list(sorted_data.values()), marker='o')

# Customize the plot
plt.title("Line Plot of PDMA Complexes")
plt.xlabel("PDMA Complex")
plt.ylabel("Molality")
plt.yscale("log")  # Set y-axis to log scale due to wide range of values
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.grid(True)

# Display the plot
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Sort the data by keys to ensure a proper line plot
# ----> 2 sorted_data = dict(sorted(selected_species.items()))
#       4 # Create the plot
#       5 plt.figure(figsize=(10, 6))
#
# NameError: name 'selected_species' is not defined

# %%
zn_species = {}
for key, value in solution.species.items():
    if 'Zn' in key:
        zn_species[key] = value

# %%
fig, ax = plt.subplots()
ax.bar(zn_species.keys(), zn_species.values())
ax.set_yscale('log')
# rotate x axis 45 degrees
plt.xticks(rotation=45, ha='right');
