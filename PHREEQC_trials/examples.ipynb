# %%
from phreeqpython import PhreeqPython
# create new PhreeqPython instance
pp = PhreeqPython('/home/jjl122/repos/irp-jjl122/tests/test_database_1.dat')
import numpy as np
import matplotlib.pyplot as plt

# %%
sol = {
    'pH': 3.0,
    'Cl': 0.02,
    'Na': 0.02,
    'Ni': 0.00001,
    'Citrate': 0.00001,
    'Dfoba': 0.00001,
    'Dma': 0.00001,
    'Dmaoh': 0.00001,
    'Malate': 0.00001,
    'Co': 0.000001,
    'Cu': 0.000001,
    'Fe': 0.000001,
    'Zn': 0.000001,
    'units': 'mol/kgw',
    'pe': 5.92,
    'temperature': 25
}
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[3], line 19
#       1 sol = {
#       2     'pH': 3.0,
#       3     'Cl': 0.02,
#    (...)
#      17     'temperature': 25
#      18 }
# ---> 19 solution = pp.add_solution(sol)
#
# File ~/miniconda3/envs/playground/lib/python3.10/site-packages/phreeqpython/phreeqpython.py:143, in PhreeqPython.add_solution(self, composition, extraneous)
#     141     inputstr += "SAVE SOLUTION "+str(self.solution_counter) + "\n"
#     142     inputstr += "END \n"
# --> 143     self.ip.run_string(inputstr)
#     144 else:
#     145     self.chain_buffer += inputstr
#
# File ~/miniconda3/envs/playground/lib/python3.10/site-packages/phreeqpython/viphreeqc.py:511, in VIPhreeqc.run_string(self, cmd_string)
#     508 errors = self._run_string(self.id_,
#     509                           ctypes.c_char_p(bytes(cmd_string, 'utf-8')))
#     510 if errors != 0:
# --> 511     self.raise_string_error(errors)
#
# File ~/miniconda3/envs/playground/lib/python3.10/site-packages/phreeqpython/viphreeqc.py:178, in VIPhreeqc.raise_string_error(self, errors)
#     176 else:
#     177     msg = 'Wrong error number.'
# --> 178 raise Exception(msg + self.get_error_string())
#
# Exception: An error occured.
# ERROR: RunString: No database is loaded

# %%
try:
    solution = pp.add_solution(sol)
except Exception as e:
    print(e)
# Out:
# An error occured.
# ERROR: RunString: No database is loaded

# %%
solution.species

# %%
# Sort the data by keys to ensure a proper line plot
sorted_data = dict(sorted(selected_species.items()))

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(list(sorted_data.keys()), list(sorted_data.values()), marker='o')

# Customize the plot
plt.title("Line Plot of PDMA Complexes")
plt.xlabel("PDMA Complex")
plt.ylabel("Molality")
plt.yscale("log")  # Set y-axis to log scale due to wide range of values
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.grid(True)

# Display the plot
plt.tight_layout()
plt.show()

# %%
zn_species = {}
for key, value in solution.species.items():
    if 'Zn' in key:
        zn_species[key] = value

# %%
fig, ax = plt.subplots()
ax.bar(zn_species.keys(), zn_species.values())
ax.set_yscale('log')
# rotate x axis 45 degrees
plt.xticks(rotation=45, ha='right');
